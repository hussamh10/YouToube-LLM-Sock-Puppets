# %% [markdown]
# ### User + Video Dataset (Binary)
#
# #### Dataset
#
# For each video:
# X = lets have a user history, playing video, suggested videos, selected video
# Y = was selected (1) or not (0)

# %%
import pandas as pd
import pickle as pkl
import numpy as np

import sys
sys.path.append('../')
from utils import *

# %%
df = pd.read_parquet('../../data/logs.parquet')

# %%
sq = df[['userId', 'search_query']].dropna()
sq = sq.groupby('userId').agg({'search_query': list}).reset_index()
sq = sq.set_index('userId')
sq = sq.to_dict()['search_query']
# Out:
#                                                 search_query
# userId
# AABA10807  [dnald trump oan, dnald trump oan interview, d...
# AAYG93273                                       [Bar Rescue]
# ABRL25174  [billy joel official video, billy joel innocen...
# ADMD65322  [uptown funk, uptown funk, uptown funk postmod...
# AFBZ98182               [jazza, jazza shorts, news new york]
# ...                                                      ...
# ZXUF35757  [ariana grande santa tell me, tasha scott coca...
# ZYLW85591        [ears flushed out, a little sound and gray]
# ZYWO62277           [mccarthy, mccarthy&sp=EgIIAQ%253D%253D]
# ZZDV35060    [hidden true crime, cord cutter news, wop song]
# ZZRP48031  [best air rifle for small game hunting, best a...
#
# [1372 rows x 1 columns]

# %%
pkl.dump(sq, open('../../data/dataset/user_search_query.pkl', 'wb'))
# Out:
# {'AABA10807': ['dnald trump oan',
#   'dnald trump oan interview',
#   'dnald trump oan interview&sp=EgIIBA%253D%253D',
#   'oan',
#   'anitra gunn',
#   'how to make lens fit in frame',
#   'how to make frame fit lenses',
#   'bannon trading cards',
#   'bannon trading cards',
#   'melanie lawson',
#   'attorney solomon esq',
#   'attorney solomon esq',
#   'attorney solomon esq divorce court',
#   'judge denise gentile',
#   'nicholas revello vs karen sangalaza',
#   'judge ellerbe',
#   'trump'],
#  'AAYG93273': ['Bar Rescue'],
#  'ABRL25174': ['billy joel official video',
#   'billy joel innocent man official video',
#   'honesty billy joel',
#   'don%27t ask me why billy joel',
#   'The Longest Time billy joel',
#   'This Is the Time billy joel'],
#  'ADMD65322': ['uptown funk',
#   'uptown funk',
#   'uptown funk postmodern jukebox',
#   'uptown funk postmodern jukebox'],
#  'AFBZ98182': ['jazza', 'jazza shorts', 'news new york'],
#  'AFME53670': ['sleepers',
#   'cubs news today',
#   'association',
#   'beatles songs',
#   'orpheus',
#   'grass roots hold on',
#   'smiling islands robbie patton',
#   'kenny loggins',
#   'kenny loggins',
#   'kenny loggins heart to heart ',
#   'elo telephone line',
#   'american breed green light',
#   'american breed step out of your mind',
#   'american breed bend me shape me',
#   'lighthouse sunny days',
#   'chicago feelin stronger every day',
#   'america i need you',
#   'america hold me tight ',
#   'america tin man ',
#   'grass roots hold on',
#   'grass roots where were you when i needed you ',
#   'grass roots hold on ',
#   'cubs news today',
#   'cubs news today',
#   'handy heater review',
#   'handy heater review',
#   'troggs girl like you',
#   'american breed green light',
#   'american breed step out of your mind',
#   'grass roots sooner or later',
#   'america today%27s the day',
#   'gerry buckley',
#   'cubs news today',
#   'cubs news today podcast'],
#  'AFVH53386': ['nancy mace caraballo'],
#  'AGXL41289': ['how to make empanada dough',
#   'how to make empanada dough',
#   'grupo frontera',
#   'scallop and angel hair pasta recipe',
#   'scallop and angel hair pasta wih pesto',
#   'scallop pesto and tomatoes',
#   'scallop pesto and tomatoes',
#   'scallop pesto and tomatoes',
#   'how to stitch ',
#   'how to duet on tiktok',
#   'how to duet on tiktok',
#   'how to duet on tiktok',
#   'how to duet on tiktok',
#   'how to duet on tiktok',
#   'how to duet on tiktok',
#   'how to duet on tiktok',
#   'how to duet on tiktok',
#   'chicken chilaquiles rojo',
#   'how to duet on tiktok',
#   'how to duet on tiktok',
#   'how to duet on tiktok',
#   'duelo sol y mar',
#   'duelo sol y mar',
#   'duelo sol y mar video',
#   'wing recipes baked',
#   'beef roast in crock pot',
#   'multiplication with fractions %22leah used two methods to find the product of 3%2F4 and 3%2F2%22'],
#  'AHFB82725': ['kate upton nude',
#   'kate upton nude',
#   'kate upton nude',
#   'kate upton nude',
#   'kate upton nude',
#   'kate upton nude'],
#  'AHFG88619': ['pen testing tutorial'],
#  'AIAU84584': ['barbie trailer',
#   'Ronyx%27s',
#   'ronyxs cities skylines',
#   'ronyxs cities skylines',
#   'ronyxs cities skylines'],
#  'AIGQ42908': ['teen  runner  of the  year',
#   'jamaican running 2022',
#   'jamaican running 2022',
#   'teen  runner  of the  year',
#   'judy austin movies',
#   'under twenty world championships',
#   'under twenty world championships',
#   'under twenty world championships',
#   'world athletics championships 2022 u20 100m',
#   'world athletics championships 2022 u20 100m',
#   'under twenty world championships',
#   'gahanna',
#   'gahanna  cook  ackee',
#   'gahanna  cook  ackee',
#   'kat theo work from home',
#   'youtube channel without face and voice tamil '],
#  'AIKD12274': ['sex o%27clock usa you%27re my man',
#   'ennio morricone extended',
#   'ennio morricone extended',
#   'morales mix',
#   'm%26m mix',
#   'm%2Bm mix',
#   'm%2Bm mix',
#   '10000 Maniacs - More Than This (Hard Club Remix)',
#   'Billie Ray Martin - Your Loving Arms (Padapella Mix)',
#   'Crystal Waters - 100%25 Pure Love (Club Mix) 1994',
#   'George Michael - Careless Whisper (Love To Infinity Mix)',
#   'Giorgio Moroder feat. Donna Summer - Carry On (Remastered Razormaid Promotional Remix)',
#   'Madonna - Don%27t Cry For Me Argentina (Miami Mix)',
#   'Maria Nayler - Naked %26 Sacred (Direct Hit Version)',
#   'Pet Shop Boys - To Step Aside (T-Crew Re-Edit)',
#   'Suzanne Palmer - Hide U (Junior Vasquez New York Club Mix)',
#   'The Bucketheads - The Bomb EP (These Sounds Fall Into My Mind)'],
#  'AIQW22291': ['Nadav Dueber',
#   'GoldenPqnda',
#   'GoldenPqnda&sp=QgIIAQ%253D%253D',
#   'mice on venus arpeggios',
#   'mice on venus arpeggios',
#   'bluejay',
#   'khanubis',
#   'couriway',
#   'in this shirt',
#   'isab btd5',
#   'eazyspeezy',
#   'so this is christmas and what have you done',
#   'happy xmas cover',
#   'happy xmas cover',
#   'phantasm',
#   'the legend of genji episode 1',
#   'the legend of genji%5C',
#   'thriller punjabi',
#   'thriller hd punjabi',
#   'thriller hd punjabi',
#   'michael reeves',
#   'isab',
#   'Ryan Higa',
#   'hasan maya higa',
#   'bust your kneecaps live'],
#  'AJEY71890': ['colbert monologue',
#   'colbert',
#   'colbert trump cards',
#   'january 6',
#   'leonard veteran holt',
#   'leonard veteran holt',
#   'leonard wwII veteran holt',
#   'leonard wwII veteran jackson tv',
#   'WWII veteran stories Leonard Holt Michigan',
#   'songs of 2015'],
#  'AJZC30289': ['12 inch cast iron',
#   '12 inch cast iron skillet',
#   'irs refund update december',
#   'irs refund update december',
#   'tommy hilfiger short snorkel coat',
#   'salt bae messi',
#   'salt bae messi',
#   'antphrodite',
#   'psychic medium ray',
#   'joe buck and scott van pelt exchange',
#   'joe buck and scott van pelt exchange',
#   '2023 psychic predictions craig hamilton',
#   'mississipi state footbal last game 2022',
#   'jeremy giambi hit in head',
#   '2023 psychic predictions',
#   '2023 psychic predictions',
#   '2023 psychic predictions',
#   '2023 psychic predictions',
#   '2023 psychic predictions'],
#  'AKTX89324': ['callie and son',
#   'callie and son',
#   'rebel in town movie 1956',
#   'paramount studios tour',
#   'paramount studios tour',
#   'paramount studios tour',
#   'paramount studios tour',
#   'paramount studios tour',
#   'paramount studios tour',
#   'paramount studios tour',
#   'the river and the wall trailer'],
#  'AKWE20184': ['nasaspaceflight',
#   'labpadre',
#   'rgv aerial photography spacex ',
#   'marcus house spacex youtube ',
#   'wai spacex',
#   'spacex live',
#   'starbase live stream',
#   'csi starbase',
#   'ocean cam',
#   'dust',
#   'oceanus dust part 2 '],
#  'ALMP62978': ['america%27s got talent worst auditions'],
#  'AMAF96901': ['because we want to billie piper ',
#   'waterloo sports reporter',
#   'waterloo sports reporter',
#   'heat wave ',
#   'vlogbrothers',
#   '90s grunge',
#   'grunge playlist',
#   '90s grunge mix',
#   'foo fighters this is a call live',
#   'kyle kinane',
#   'brown noise',
#   'brown noise',
#   'simpsons hockey',
#   'prince harry stephen colbert',
#   'troy and abed in the morning',
#   'troy community',
#   'rug cleaning'],
#  'AMIW68733': ['cigerates out the wjndow sped up',
#   'hes sorry never mag.lo',
#   'not allowed remix',
#   'its not fair x hes sorry',
#   'norman f rockwell lana del rey',
#   'hes sorry x hey kids',
#   'are you even paying attention to me right now',
#   'i don%27t ever wanna see you and i never wanna miss you again ',
#   'red means i love you',
#   'tous les memes  sped',
#   'call me plenka',
#   'black mambo glass animals',
#   'subs not working use this',
#   'eventually slowed',
#   'eventually slowed',
#   'whatever i%27ve done i%27ve done it for love sped up',
#   'eventually sped up',
#   'bring it back sped up',
#   'sex with a ghost ',
#   'bring it back sped up',
#   'my bodys looking wrong slowed',
#   'radiohead no surprises sped up',
#   'radiohead no surprises ',
#   'radiohead no surprises slowed',
#   'everlong foo fighters',
#   'kerosene sped up instrumental ',
#   'girl you really got a hold on me so this isn%27t just puppy love',
#   'girl you really got a hold on me so this isn%27t just puppy love',
#   'kill bill sza',
#   'yeah my boyfriend%27s pretty cool but he%27s not as cool as me',
#   'you can be the boss lana del rey',
#   'under the influence chris brown sped up',
#   'two against one',
#   'yeah my boyfriend%27s pretty cool but he%27s not as cool as me',
#   'sick as a dog lana',
#   'fame and fortune subliminals',
#   'in the back of my mind you died i killed you',
#   'space ghost coast to coast',
#   'themla ofdream',
#   'wespn',
#   'kill bill',
#   'insant manifestation',
#   'fame and fortune subliminals',
#   'im like a devil you cant get me off your mind',
#   'i drop it down i pick it upyou cant get me off your mind',
#   'i drop it down i pick it upyou cant get me off your mind labna',
#   'you cant get me off your mind labna',
#   'Don%E2%80%99t Call Me Angel (MASRY Remix)',
#   'Don%E2%80%99t Call Me Angel ',
#   'sharp jawline subliminal',
#   'insant manifestation',
#   'wish granter',
#   'i got a man but i want you',
#   'themediumwitch',
#   'package never gets lost subliminal',
#   'package never gets lost subliminal',
#   'make them contact you',
#   'make them add you on social media meditation',
#   'desired person flirts with you',
#   'desired person flirts with you',
#   'desired person flirts with you',
#   'make them forgive you',
#   'make them forget',
#   'wish granter',
#   'black tourmaline crystal meditation',
#   'mark reynolds subliminal',
#   'nsfw subliminal',
#   'anyone can start again not through love',
#   'ive got my eye on you',
#   'nevedimah',
#   'west coast instrumental slowed',
#   'norman f rockwell lana del rey',
#   'dead men dont r',
#   'pink rover scene queen',
#   'banshee don%27t touch me',
#   'banshee fairy metal',
#   'nyusha',
#   '%D0%BD%D0%B5%D0%B2%D0%B8%D0%B4%D0%B8%D0%BC%D0%B0%D1%8F',
#   'redchinawave%E2%80%93%D0%BE%D1%82%D0%BC%D0%B5%D0%BD%D1%8F%D0%B9',
#   'black cat russian song',
#   'black cat lepc',
#   'chornoi koshki',
#   ' 2%3A14%3A52 NOW PLAYING  %D0%A7%D1%91%D1%80%D0%BD%D1%8B%D0%B5 %D0%9A%D0%BE%D1%88%D0%BA%D0%B8',
#   '%D0%A7%D1%91%D1%80%D0%BD%D1%8B%D0%B5 %D0%9A%D0%BE%D1%88%D0%BA%D0%B8',
#   '%D1%87%D1%91%D1%80%D0%BD%D1%8B%D0%B5 %D0%BA%D0%BE%D1%88%D0%BA%D0%B8 %D0%BD%D0%B5%D1%82 %D0%BE%D0%BF%D0%B0%D1%81%D0%BD%D0%B5%D0%B9',
#   'sunlight hoizer but you flew too close to the sun',
#   'sunken sun russian movie',
#   'kill bill sped up',
#   'kiss it better sped up',
#   'the only thing we share is one last name',
#   'brooklyn baby lana del rey',
#   'yes to heaven lana del rey',
#   'are you even paying attention to me right now',
#   'wine pon you sped up',
#   'ill keep you safe',
#   'trust issues the weeknd',
#   'jealous girl lana del rey',
#   'if i can%27t have you no one should ',
#   'sipping champagne drunk tears drunk sex',
#   'tous le memes',
#   'edit audio lights down low',
#   'starboy sped up',
#   'way down we go',
#   'clear twenty one pilots',
#   'idkhbtfm bleed magic modern day cain choke a new invention',
#   'idkhbtfmchoke',
#   'my type',
#   'hollywood undead everywhere i go',
#   'nuketown ski mask',
#   'ski mask the slump god foot fungus',
#   'look at me instrumental',
#   'tek it best part looped',
#   'willow smith female energy',
#   'willow smith wait a minute',
#   'kerosene sped up instrumental',
#   'me and your mama sped up part onkly',
#   'just cool don%27t panic darling sped up loop',
#   'right here chase slowed',
#   'confidence playlist',
#   'escapism slowed',
#   'escape from divinity part 1 church',
#   'shut eye stealing sheep',
#   'vampire people in planes',
#   'sirens black panther',
#   'skyfall slowed',
#   'way down we go slowed',
#   'Stargirl Interlude ',
#   'maneater nelly',
#   'wish granter',
#   'desired person loses friends subliminal ',
#   'swang tiktok remix',
#   'change tik tok song',
#   'sahara',
#   'shootouts',
#   'shootouts instrumental speed up',
#   'help yourself phonk remix',
#   'youre rage vent playlist',
#   'trauma playlist',
#   'why canti be better playlist',
#   'forget pogo tiktok remix',
#   'no surprises',
#   'cigarettes out the window instrumental sped up'],
#  'AMNZ92026': ['magic happens parade',
#   'magic happens parade',
#   'magic happens parade',
#   'magic happens parade',
#   'the cadets 12.25',
#   'phantom regiment 2006',
#   'phantom regiment 2003',
#   'phantom regiment 2003',
#   'let it burn tony awards',
#   'let it burn tony awards',
#   'osumb',
#   'osumb&sp=CAI%253D',
#   'tbdbitl',
#   'tbdbitl&sp=CAI%253D',
#   'ohio state marching band',
#   'ohio state marching band&sp=CAI%253D',
#   'brazil',
#   'beetlejuice san francisco',
#   'beetlejuice san francisco',
#   'beetlejuice san francisco',
#   'beetlejuice san francisco',
#   'beetlejuice musical',
#   'mera mangle'],
#  'AOEJ59128': ['blubber',
#   'greenville christmas update 2022',
#   'greenville update',
#   'spil0',
#   'Shard',
#   'greenville update',
#   'greenville update',
#   'how to plow snow in greenville roblox',
#   'muye',
#   'greenville',
#   'greenville',
#   'greenville',
#   'greenville',
#   'greenville',
#   'best%20acoustic%20guitar%20performance',
#   'best acoustic guitar performance',
#   'leo kottke',
#   'eric johnson'],
#  'APID18430': ['rumble'],
#  'APLA78990': ['how to make candy cane decorations ',
#   'how to make candy cane christmas decorations ',
#   'how to make small candy cane christmas decorations ',
#   'how to make small candy cane christmas decorations ',
#   'how to make dough ornaments that last',
#   'how to make dough ornaments that last',
#   'what can you use to make 2 inch candy cane decorations',
#   'hacks'],
#  'APVF43442': ['undertaker 1998 theme',
#   'undertaker 1998 theme',
#   'white horse',
#   'be alright kendrick lamar',
#   'memphis wrestling martin theme',
#   'k toomer theme',
#   'cora jade theme',
#   'chavo last wcw theme'],
#  'AQQO40128': ['big bites mukbang asmr',
#   'driver booster key',
#   'jon krakauer interview ',
#   'jon krakauer interview cnn ',
#   'cucumber song',
#   'cucumber song',
#   'cucumber song',
#   'ms rachel baby'],
#  'AQTG43072': ['final navide%C3%B1a tigres vs america'],
#  'AQTH24595': ['rush live  professional reaction',
#   'ron%27s trains and things ',
#   'ron%27s trains and things  styrene',
#   'ron%27s trains and things  styrene'],
#  'AQXJ46751': ['spaghetti squash in pressure cooker'],
#  'ARBH48516': ['family guy',
#   'family guy season 21 episode 9',
#   'family guy season 21 episode 10',
#   'mandy rose',
#   'hollow high on life',
#   'games4kickz',
#   'games4kickz grounded',
#   'shohei crying',
#   'crying for ichiro',
#   'crying for ichiro',
#   'family guy season 21 episode 10',
#   'family guy season 21 episode 9',
#   'tree man',
#   'she loves the rain',
#   'snl axl rose sebastian bach',
#   'alyssa white gluz',
#   'trailblazers reporter mascot',
#   'street trash',
#   'belle anime song',
#   'belle anime song',
#   'belle anime song',
#   'belle anime song'],
#  'ARNR49737': ['hvob'],
#  'ARZW21993': ['taylor swift', 'taylor swift'],
#  'ASAV85341': ['ghost riders in the sky johnny cash',
#   'ghost riders in the sky johnny cash',
#   'ghost riders in the sky johnny cash',
#   'ghost riders in the sky johnny cash',
#   'ghost riders in the sky spiderbait',
#   'ghost riders in the sky 38 special',
#   'ghost riders in the sky 38 special',
#   'ghost riders in the sky 38 special',
#   'ghost riders in the sky 38 special',
#   'zefrank1',
#   'ohio%2Ccsny',
#   'ohio%2Ccsny'],
#  'ASFN19775': ['cnbc'],
#  'AUAE57733': ['vanilla funk',
#   'vanilla funk college ',
#   'justin heideman',
#   'justin heideman',
#   'walgreens couponing this week',
#   'walgreens couponing this week',
#   'cvs couponing this week',
#   'low calorie meals',
#   'frugal fit mom',
#   'post 10 truck',
#   'nik and iv diy',
#   'nik and iv diy',
#   'walgreens couponing this week',
#   'do it on a dime target salvage store',
#   'do it on a dime target salvage store',
#   'walgreens couponing this week'],
#  'AUQQ93226': ['vaush',
#   'bladee',
#   'bladee western union',
#   'bladee western union',
#   'athens mountain singers',
#   '1940s rap',
#   'horrible girl and the hot mess band',
#   'vaush satanist',
#   'princess jellyfish opening',
#   'princess jellyfish opening',
#   'finn mckenty ',
#   'beau of the fifth column',
#   'thought slime',
#   'cybersix full episodes',
#   'cybersix full episodes',
#   'ben 10 generator rex crossover',
#   'ben 10 heroes united',
#   'rural medicine',
#   'best morrowind mods',
#   'skyblivion',
#   'rainbow 6 siege extraction',
#   'witchfinger live',
#   'witchfinger tallahassee',
#   'witchfinger tllyhc',
#   'tllyhc',
#   'tllyhc',
#   'colleen green',
#   'tllyhc bad anxiety',
#   'anhinga vs cormorant',
#   'fly me to the moon evangelion',
#   'hellworld',
#   'night on the midnight railroad full',
#   'waratetta',
#   'solty rei ending',
#   'cruel angel%27s thesis',
#   'colleen green bandcamp livestream',
#   'the new babylon film',
#   'philosophy tube',
#   'sojus 1 new babylon',
#   'new babylon',
#   'new babylon',
#   'opulence',
#   'a cruel angel%27s thesis',
#   'full metal panic opening'],
#  'AVNJ40636': ['basemental mods weed strains',
#   'pok%C3%A9mon legends arceus leaks',
#   'mass effect 3 dlc',
#   'master duel meta eldlich',
#   'avengers game kate',
#   'elden ring lighting slash',
#   'dance monkey cover baby'],
#  'AWGV77815': ['how to send suitcase by fedex',
#   'olivia rodrigo ariana',
#   'ir20v',
#   'olivia rodrigo driver%27s license ariana grande',
#   'halsey power and love',
#   'you should be sad halsey',
#   'halsey new americana live'],
#  'AWHP38252': ['cosmic revenge ',
#   'cosmic revenge  pat',
#   're 3 remake save import',
#   'undead chronic',
#   'ASRock B650M PG RIPTIDE',
#   'amd version of rtx 3080',
#   'amd version of rtx 3080',
#   'midnight club 3 dub edition cutscenes',
#   'midnight club 3 dub edition atlanta',
#   'midnight club 3 dub edition atlanta',
#   'midnight club 3 dub edition atlanta',
#   'midnight club 3 dub edition atlanta',
#   'bowflex infomercial 2008',
#   'bowflex 1 2008',
#   'how she move ending',
#   'how she move trailer',
#   'how she move trailer german',
#   'svr 2007',
#   'wwe smackdown vs raw 2007 jillian hall ',
#   'wwe ruthless aggression divas',
#   'victoria wwe studio%27cilps',
#   'wwe ruthless aggression divas',
#   'how she move-respect',
#   'elektra intro',
#   'bowflex size matters',
#   'wwe smackdown vs raw 2007 jillian hall',
#   'wwe smackdown vs raw 2007 jillian hall',
#   'wwe smackdown vs raw 2007 jillian hall',
#   'bowflex size matters',
#   'how she move tv spot',
#   'how she move ending',
#   'midnight club 3 dub edition cutscenes',
#   'smackdown vs raw 2007',
#   'midnight club 3 dub edition atlanta',
#   'midnight club 3 dub edition remix original riders ',
#   'midnight club 3 dub edition remix original riders ',
#   'midnight club 3 dub edition dre',
#   'midnight club 3 dub edition dre',
#   'midnight club 3 dub edition dre',
#   'midnight club 3 dub edition remix original riders ',
#   'smackdown vs raw 2007',
#   'wwe ashley massaro death',
#   'smackdown vs raw 2007',
#   'midnight club 3 dub edition cutscenes',
#   'the boondocks full episodes',
#   'edge wrestlemania',
#   'edge wrestlemania 21',
#   'edge after wrestlemania 21',
#   'edge wrestlemania 21',
#   'edge cashes in money inthe bank john cena',
#   'into the blue jessica alba',
#   'wwe intro',
#   'smackdown vs raw 2007',
#   'undead chronic',
#   'ribby the party frog'],
#  'AWTB33481': ['lenovo yoga 6', 'funny animal videos', 'ninja kids'],
#  'AWTY75101': ['andrew tate',
#   'andrew%20tate&themeRefresh=1',
#   'andrew tate',
#   'andrew tate',
#   'andrew tate'],
#  'AXAY70039': ['paul and morgan',
#   'mama koala cloth diapers',
#   'mama koala cloth diapers',
#   'mama koala cloth diapers'],
#  'AYBU33014': ['monstrum 3x30 stealth fixed power scope review',
#   'monstrum 3x30 stealth fixed power scope review',
#   'monstrum 3x30 stealth fixed power scope review',
#   'monstrum 3x30 stealth fixed power scope review',
#   'CVLIFE 2.5-10x40e Red %26 Green Illuminated Rifle Scope Mil-dot Gun Scope Green Laser Combo',
#   'CVLIFE 2.5-10x40e Red %26 Green Illuminated Rifle Scope Mil-dot Gun Scope Green Laser Combo',
#   'magnet fishing',
#   'magnet fishing',
#   'magnet fishing',
#   'Monstrum Marksman 5X Ultracompakt Micro Prism Scope',
#   'Monstrum Marksman 5X Ultracompakt Micro Prism Scope',
#   'monstrum stealth 4x30 fixed magnification scope review',
#   'Monstrum Stealth 4x30 Fixed Magnification Scope',
#   'monstrum stealth 4x30',
#   'monstrum 4x30',
#   'how to interact with controller on wow',
#   'how to set up controller for wow',
#   'Malik Benson',
#   'Malik Benson'],
#  'AYKX60895': ['volcano eruption 2022',
#   'frosty the snowman song',
#   'frosty the snowman song',
#   'rudolph the red nosed reindeer',
#   'impossible channel'],
#  'AZAJ26811': ['i will stand by you',
#   'christmas albums',
#   'medieval christmas music',
#   'medieval christmas music',
#   'pentatonix sound of silence',
#   'pentatonix ',
#   'watermelon sugar',
#   'watermelon sugar',
#   'I will stand by you',
#   'I will stand by you',
#   'i will stand by you pretenders',
#   'I will stand by you',
#   'damar hamlin injury',
#   'damar hamlin injury',
#   'damar hamlin injury',
#   'damar hamlin injury',
#   'voyager 4d ',
#   'Chernoble dogs',
#   'Chernoble dogs',
#   'Chernoble dogs',
#   'Chernoble dogs',
#   'Chernoble blue dogs',
#   'Chernoble blue dogs',
#   'Chernoble dogs',
#   'Chernoble blue dogs',
#   'mat and savanna shaw christmas songs',
#   'mat and savanna shaw christmas songs',
#   'Peter Paul and Mary The rising of the moon',
#   'voyager'],
#  'BAFC57201': ['court tv live stream',
#   'court tv live stream',
#   'camarones ecuador',
#   'camarones ecuador',
#   'camarones ecuador',
#   'camarones ecuador',
#   'shemale in the bronx',
#   'shemale in the bronx',
#   'shemale  im bronx ny',
#   'shemale  im bronx ny',
#   'shemale  im bronx ny',
#   'shemale  im bronx ny',
#   'shemale  im bronx ny',
#   'shemale  im bronx ny',
#   'guayaquil shemale',
#   'guayaquil shemale',
#   'guayaquil shemale',
#   'guayaquil shemale',
#   '2006 chrysler left side',
#   '2006 chrysler left side',
#   '2006 chrysler left side mirror replacement',
#   '2006 chrysler pacifica',
#   '2006 chrysler pacifica left side mirror',
#   '2006 chrysler pacifica left side mirror',
#   'cuando un amigo se va alberto cortez y facundo cabral',
#   'new york new york frank sinatra',
#   'guayaquil shemale',
#   '2006 chrysler left side',
#   'camarones ecuador',
#   'camarones ecuador'],
#  'BAXN63660': ['YOUNG THUG LIVE IN COURT RIGHT NOW',
#   'YOUNG THUG LIVE IN COURT RIGHT NOW iq'],
#  'BBFH19997': ['chick fil a',
#   'how were social security numbers issed in 1958',
#   'how were social security numbers issed in 1958',
#   'marinated tomato salad',
#   'pro power saver review',
#   'pro power saver review',
#   'ruggles',
#   'ruggles performance',
#   'ruggles performance',
#   'ruggles performance buick v6',
#   'ruggles performance buick v6',
#   'ruggles performance buick v6',
#   'DAN',
#   'china anne mcclain youtube channel',
#   'canning seafood',
#   'canning seafood',
#   'canning seafood',
#   'ryan hall',
#   'yogurt pretzel recipe',
#   'alabama prepper'],
#  'BDFP66930': ['lucky star',
#   'judgemental critter',
#   'judgemental critter',
#   'spooky loves boba',
#   'mell.bunnie',
#   'mell.bunnie',
#   '2012 casey jones',
#   '2012 casey jones',
#   '2012 casey jones',
#   '2012 casey jones',
#   'rottmnt donnie',
#   'rottmnt donnie',
#   'wednesday dance'],
#  'BDFT90503': ['nordic animism',
#   'inungard and utangard crawford',
#   'inungard and utangard crawford',
#   'practicing animism',
#   'einar selvik',
#   'wardruna',
#   'animist healing songs',
#   'wardruna',
#   'animist healing songs',
#   'animist healing songs',
#   'healiung chants earth',
#   'healiung chants earth',
#   'healiung chants earth',
#   'healiung chants earth',
#   'bear totem',
#   'bear totem nordic'],
#  'BDJX90721': ['scottsdale bible church',
#   'power miter saw tricks tips',
#   'here with us joy williams lyrics',
#   'christmas is real travis cottrell ',
#   'o come all ye unfaithful',
#   'winter wonder scottsdale bible',
#   'christmas for the valley scottsdale bible',
#   'psalm 46 hymn',
#   'christmas movie',
#   'christmas movie&sp=EgIYAg%253D%253D',
#   'christmas movie&sp=EgQQBBgC',
#   'christmas movie free with ads',
#   'christmas movie free with ads',
#   'christmas movie free with ads lifetime',
#   'undercover christmas',
#   'undercover christmas 2003',
#   'undercover christmas 2003',
#   'a christmas mystery 2014',
#   'a christmas mystery 2014',
#   'home by christmas full movie 2006',
#   'home by christmas full movie 2006',
#   'christmas movie widow mom children old house',
#   'christmas movie widow mom children old house',
#   'christmas movie widow mom children old house',
#   'christmas movie widow mom children old house&sp=EgIQBA%253D%253D',
#   'christmas movie mom children old house',
#   'christmas movie mom children old house',
#   'merry swissmas movie ',
#   'nine lives of christmas',
#   'just in time for christmas',
#   'accidental family movie',
#   'accidental family movie',
#   'kenny g miracles the holiday album',
#   'winter wonder scottsdale bible',
#   'here with us joy williams lyrics',
#   'omni talk fast five',
#   'lifetime christmas movies',
#   'lifetime christmas movies',
#   'lifetime christmas movies'],
#  'BDNJ77630': ['january 6th committee hearing',
#   'miley cyrus backyard sessions',
#   'autoglass assassins',
#   'andrew rodowsky',
#   'rodowsky',
#   'funny',
#   'tv show bloopers',
#   'tom petty live',
#   'saturday night live',
#   'nbc miley%27s new year%27s eve party 2022',
#   'nbc miley%27s new year%27s eve party 2022',
#   'hairstyles for women over 40'],
#  'BDRS71403': ['girl talk feed the animals',
#   'unusual memes',
#   'brian david gilbert',
#   'unusual memes',
#   '5 minute mobility stretch',
#   'barefoot strength',
#   'prozd',
#   'prozd',
#   'prozd'],
#  'BDSO38233': ['jon courson',
#   'danny gokey mary did you know lyrics',
#   'claudio arrau beethoven sonatas',
#   'perfectly loved rachael lampa toby mac',
#   'i pray for your healing that circumstances would change',
#   'klove radio'],
#  'BEUX79179': ['all taylor swift music videos',
#   'how to clean baseboards without bending over using swiffer',
#   'kt food stories'],
#  'BFKS24123': ['ESV Study Bible Hardcover',
#   'HUNTACE Gun Cleaning Kit Supplies for Shotgun%2C Rifle%2C 9mm%2F.38%2F.357%2F.22 %2F.40%2F.45%2F.270%2F7mm%2F.30%2F8mm%2CPistol%2C Rifle%EF%BC%8CHandgun Cleaning Kit for Men Bronze Brushes with Carrying Case',
#   'HUNTACE Gun Cleaning Kit ',
#   'seenda humidc7702 humidifier',
#   'seenda humidifier',
#   'FMK 9C1 G2 9mm 4%22 Barrel 14%2B1 Round Black Carbon Steel Slide Cold Hammer Forged Barrel Black Frame with Interchangeable Backstraps',
#   'FMK 9C1 G2 9mm 4%22 Barrel 14%2B1 Round Black Carbon Steel Slide Cold Hammer Forged Barrel Black Frame with Interchangeable Backstraps',
#   'Rock Island 51655 MAPP FS *CA Compliant* Single%2FDouble 9mm Luger 4.4%22 10%2B1 Black Polymer Grip%2FFrame Grip Black Parkerize',
#   'Rock Island 51655 MAPP FS *CA Compliant* Single%2FDouble 9mm Luger 4.4%22 10%2B1 Black Polymer Grip%2FFrame Grip Black Parkerize',
#   'EAA CORP GIRSAN MC9 9MM 4.2%22 BARREL 17-ROUNDS FAR-DOT OPTIC',
#   'American Tactical Scout SGA 12 Gauge Semi Auto 26%22 Shotgun',
#   'SDS TISAS PX-9 9MM 4.1 Black IRON SIGHTS',
#   'SDS TISAS PX-9 9MM 4.1 Black IRON SIGHTS',
#   'Skip to the beginning of the images gallery DIAMONDBACK DBAM29 SUB-COMPACT 9MM 3.5%22 BARREL 17-ROUNDS 3-DOT SIGHTS',
#   ' DIAMONDBACK DBAM29 SUB-COMPACT 9MM 3.5%22 BARREL 17-ROUNDS 3-DOT SIGHTS',
#   ' DIAMONDBACK DBAM29 SUB-COMPACT 9MM 3.5%22 BARREL 17-ROUNDS 3-DOT SIGHTS',
#   ' DIAMONDBACK DBAM29 9MM 3.5%22 BARREL 17-ROUNDS',
#   ' DIAMONDBACK DBAM29 9MM 3.5%22 BARREL 17-ROUNDS',
#   ' DIAMONDBACK  9MM 3.5%22 BARREL 17-ROUNDS',
#   'Tapco Intrafuse Steel AR Stock Wrench',
#   'little drummer boy',
#   'little drummer boy',
#   'EMPEROR FIREARMS MXP12 12 Gauge 18.5in',
#   'EMPEROR FIREARMS MXP12 12 Gauge 18.5in',
#   'EMPEROR FIREARMS MXP12 12 Gauge 18.5in',
#   'BRG9 ',
#   'BRG9 ',
#   'BRG9 ',
#   'BRG9 ',
#   'BRG9 ',
#   'BRG9 ',
#   'northstar air compressor 20 gallon ',
#   'Goodyear. 8 Gallon Quiet. Oil-Free Horizontal Air Compressor. Portable with Handle and Wheels',
#   'Fini Advanced%E2%84%A2 3-Gallon 150 PSI Portable Electric Hot Dog Air Compressor',
#   'BRG9 Elite 9mm Pistol with 4 Inch Barrel',
#   'BRG9 Elite 9mm Pistol with 4 Inch Barrel',
#   'BRG9 Elite 9mm Pistol with 4 Inch Barrel',
#   'BRG9 Elite 9mm Pistol with 4 Inch Barrel',
#   'BRG9 Elite 9mm Pistol with 4 Inch Barrel',
#   'BRG9 Elite 9mm Pistol with 4 Inch Barrel',
#   'BRG9 Elite 9mm Pistol with 4 Inch Barrel',
#   'Rex Zero 9mm Pistol',
#   'Kel-Tec Sub-2000 Gen2 9mm Carbine with Midnight Bronze Finish',
#   'Taurus 627 Std 357 RemMag 4%22 Ported 7rd Fixed Sight Ribber Grip Matte SS',
#   'Firefield BattleTek Grn Laser Sight',
#   'Firefield BattleTek Grn Laser Sight',
#   'Firefield BattleTek Grn Laser Sight',
#   'RUGER 10%2F22 SEMI-AUTO',
#   'RUGER 10%2F22 SEMI-AUTO',
#   'Allen Thrust Soft Crossbow Case',
#   'PSA DAGGER COMPACT 9MM PISTOL',
#   'PSA DAGGER COMPACT 9MM PISTOL',
#   'PSA DAGGER COMPACT 9MM PISTOL',
#   'PSA DAGGER COMPACT 9MM PISTOL',
#   'GSPSCN Red Tire Inflator Heavy Duty Double Cylinders%2C Portable Metal DC 12V Air Compressor%2C 150PSI Tire Pump with Adapter for Car',
#   'GSPSCN Red Tire Inflator Heavy Duty Double Cylinders%2C Portable Metal DC 12V Air Compressor%2C 150PSI Tire Pump with Adapter for Car',
#   'GSPSCN Silver Tire Inflator Heavy Duty Double Cylinders',
#   'GSPSCN Silver Tire Inflator Heavy Duty Double Cylinders',
#   'Phoenix Arms HP22A 22LR 3IN',
#   'Chiappa Firearms 401120 1911-22 22 LR SAO 5%22 10%2B1 Hogue Rubber Grip Tan Slide',
#   'GSG GERG2210FF FireFly 22 LR 4%22 10%2B1 Black w%2FPolymer',
#   'GSG GERG2210FF FireFly 22 LR 4%22 10%2B1 Black w%2FPolymer',
#   'Phoenix Arms 22 caliber',
#   'Phoenix Arms 22 caliber',
#   'Phoenix Arms 22 caliber',
#   'Phoenix Arms 22 caliber',
#   'Phoenix Arms 22 caliber',
#   'phoenix arms 22 caliber pistol',
#   'phoenix arms 22 caliber pistol',
#   'phoenix arms 22 caliber pistol',
#   'will a jennings 22 magazine work in the phoenix arms 22 caliber pistol',
#   'will a jennings J 22 magazine work in the phoenix arms 22 caliber pistol',
#   'will a jennings J 22 magazine work in the phoenix arms 22 caliber pistol',
#   'will a jennings J 22 magazine work in the phoenix arms 22 caliber pistol',
#   'will a jennings J 22 magazine work in the phoenix arms 22 caliber pistol',
#   'will a jennings J 22 magazine work in the phoenix arms 22 caliber pistol',
#   'will a jennings J 22 magazine work in the phoenix arms 22 caliber pistol',
#   'Phoenix Arms HP22 22LR Pocket Pistol',
#   'Phoenix Arms HP22 22LR Pocket Pistol',
#   'Phoenix Arms HP22 22LR Pocket Pistol',
#   'Phoenix Arms HP22 22LR Pocket Pistol'],
#  'BFMW45714': ['i know victoria%27s secret song',
#   'an outbreak of vitas gerulaitis',
#   'best moisturizer for men',
#   'i know victoria%27s secret song music video',
#   'jax i wanna hold your hand',
#   'rolling stones memory motel',
#   'mad men i%27m a man',
#   'an outbreak of vitas gerulaitis',
#   'howard stern how dare you greta',
#   'how dare you greta',
#   'how dare you greta thunberg loop',
#   'goodfellas joe pesci whacked',
#   'danielle brisebois new radicals',
#   'lithuanian models',
#   'lithuanian models',
#   'lithuanian women',
#   'Pele Richard Nixon',
#   'johnny adams my heart is hanging%27 heavy',
#   'silvio drives adriana',
#   'Multiple IRAs',
#   'mount airy lodge commercials',
#   'edita vilkeviciute',
#   'epmd you gots to chill',
#   'BBC show about holocaust hero who saved children',
#   'nicholas winton surprise',
#   'this time tomorrow the kinks',
#   'no sex until marriage',
#   'no sex until marriage front 242',
#   'nypd blue holly and the blowfish',
#   'fredo corleone murdered'],
#  'BFOP22622': ['macarthur park richard harris'],
#  'BFTE61179': ['rd 50 spotify',
#   '6900 xt vs 6950 xt 4k',
#   '6900 xt vs 6950 xt 4k',
#   '6900 xt vs 6950 xt 4k',
#   'next generation video games',
#   '6750 xt 4k',
#   '6750 xt 4k',
#   '6750 xt powercolor ',
#   '6750 xt powercolor ',
#   '6750 xt powercolor ',
#   'rx 6800 xt 4k test ',
#   'rx 6800 xt 4k test full seting',
#   'rx 6800 xt 4k test full seting&sp=QgIIAQ%253D%253D',
#   'rx 6800 xt 4k test full seting&sp=QgIIAQ%253D%253D',
#   'rx 6800 xt 4k test full seting&sp=QgIIAQ%253D%253D',
#   'rx 6800 xt 4k test full seting&sp=QgIIAQ%253D%253D',
#   'rx 6800 xt 4k test full seting&sp=QgIIAQ%253D%253D',
#   'rx 6800 xt 4k test full seting&sp=QgIIAQ%253D%253D',
#   'rx 6800 xt 4k test full seting&sp=QgIIAQ%253D%253D',
#   '6800 xt 4k gaming ',
#   'the weeknd ft 21 savage',
#   'apparently kid',
#   'apparently kid',
#   'cari%3Bo es solo una face trailer'],
#  'BGTV77361': ['juicystar007',
#   'mikayla nogueira',
#   'best makeup techniques for covering acne',
#   'stephanie buttermore',
#   'how to dress for your body shape',
#   'stephanie buttermore',
#   'stephanie buttermore',
#   'greg doucette fully rae kristina',
#   'greg doucette fully raew kristina',
#   'greg doucette eats like ally',
#   'freely',
#   'freelee',
#   'freelee',
#   'freelee weight loss',
#   'greg doucette eats',
#   'greg doucette  and ally',
#   'q and a greg doucette '],
#  'BHAA59767': ['one minute videos',
#   'montell fish fall in love with you',
#   'sick trailer 2022',
#   'nct love talk',
#   'missing trailer 2023',
#   'luminous visions',
#   'luminous debut album visions',
#   '1the9 blah',
#   'are you there god it%27s me margaret trailer',
#   'seventeen hot mv'],
#  'BHDH24366': ['kikopup dog return toy', 'couples therapy showtime'],
#  'BHED19103': ['dhitman  yt live',
#   'pole vault final 2022',
#   'mens pole vault final',
#   'how to calm a dog down',
#   'how to calm a dog down with anxiety',
#   'sandi morris 5m',
#   'diamond league brussels 2016',
#   'diamond league brussels 2016 pole vault'],
#  'BHTM19194': ['hannah montana full episodes',
#   'hannah montana full episodes',
#   'wizards of waverly place full episodes',
#   'infiniti g35 serpentine belt squeal',
#   'infiniti g35 serpentine belt squeal',
#   'infiniti g35 serpentine belt squeal'],
#  'BIGO51990': ['sabaton reaction',
#   'three kingdoms 2010 episode 20',
#   'three kingdoms episode 19',
#   'three kingdoms episode 21',
#   'ans overwatch league highlights',
#   'ans overwatch league highlights&sp=EgIIBQ%253D%253D',
#   'tom and jerry anime',
#   'tom and jerry japanese',
#   'tom and jerry meme',
#   'battlebots 2023',
#   'battlebots slugfest 2022',
#   'battlebots 2023 episode 1',
#   'battlebots 2023 episode 1',
#   'battlebots season 7 episode 1 '],
#  'BIPH25039': ['grocery music 1975 '],
#  'BIQY96972': ['jiwoo stray k%C4%B1ds'],
#  'BJDQ71386': ['trigun stampede reaction',
#   'trigun stampede reaction',
#   'trigun stampede reaction',
#   'trigun stampede reaction'],
#  'BJMA92086': ['bloomberg live', 'royal performance hayley westenra'],
#  'BKHD22958': ['full bloom bl eng sub ',
#   'perfect world ep 90',
#   'dragon day you%27re dead season 3',
#   'swallowed star episode 68',
#   'swallowed star episode 68',
#   'swallowed star episode 68',
#   'swallowed star episode 68',
#   'swallowed star episode 68',
#   'swallowed star episode 68',
#   'weather news'],
#  'BKKU45473': ['twas Night Before Christmas',
#   'twas the Night Before Christmas',
#   'twas the Night Before Christmas rankin',
#   'twas the Night Before Christmas rankin',
#   'twas the Night Before Christmas rankin bass',
#   'jack frost 1979',
#   'a charlie brown christmas',
#   'anabelles wish'],
#  'BLKN75687': ['buxton from the air',
#   'how to replace a headlight on a 2017 ford escape',
#   'how to replace a headlight on a 2017 ford escape',
#   'news today',
#   'dolly parton miley cyrus'],
#  'BMED54034': ['affinity publisher'],
#  'BMRR61987': ['501 escape room level 120 ',
#   'adventure escape mysteries',
#   'adventure escape mysteries on thin ice',
#   'adventure escape mysteries on thin ice chapter 1',
#   'adventure escape mysteries on thin ice chapter 2'],
#  'BOBY45441': ['flo rida christmas song',
#   'slice night by the temptations',
#   'the temptation silent night lyrics',
#   'james brown santa claus go straight to the ghetto '],
#  'BOED43990': ['live never play on construction sites',
#   'PAW PATROL&sp=mAEB',
#   'medcram covid19 china',
#   'medcram'],
#  'BOGQ75226': ['palaye royale beds are burning',
#   'palaye royale line it up lyrics',
#   'palaye royale pain',
#   'palaye royale off with the head lyrics',
#   'puscifer vagina mine',
#   'puscifer undertaker renholder mix lyrics',
#   'puscifer rev 22 20',
#   'APC the doomed lyrics',
#   'him right here in my arms lyrics',
#   'him wicked game lyrics',
#   'apocalyptica bittersweet',
#   'Ghost he Is lyrics',
#   'Ghost call me little sunshine',
#   'rallo tubbs fuck christmas',
#   'rallo tubbs fuck christmas',
#   'cleveland jr rap uncensored',
#   'cleveland a ra ra boom de ay',
#   'american dad daddys gone',
#   'adventurequest frostvale',
#   'adventurequest frostvale&sp=CAI%253D',
#   'melodia',
#   'melodia instrument',
#   'melodica instrument',
#   'adventurequest elite necromancer',
#   'adventurequest elite necromancer'],
#  'BOOH35374': ['loom knitting pot holders',
#   'loom knitting pot holder squares together',
#   'loom knitting pot holder',
#   'vanilla ice'],
#  'BPUS66090': ['bad axe film trailer',
#   'disc golf putting championship ',
#   'disc golf putting championship ',
#   'disc golf putting championship ',
#   'detroit lions vs green bay packers'],
#  'BQMT60961': ['mike the scavenger', 'mike the scavenger'],
#  'BQUT24777': ['before he cheats lyrics',
#   'i don%27t care anymore phil collins ',
#   'some nights fun',
#   'my favorite things ',
#   'caldwell presbyterian church',
#   'the lazy song',
#   'i dont care anymore',
#   'Before he cheats',
#   'some nights fun',
#   'my favorite things',
#   'waves mister probz',
#   'kool benee',
#   'i hope you dance lee ann womack',
#   'we are the champions lyrics',
#   'we are the champions ',
#   'radiohead',
#   'boss b doja cat',
#   'anti hero taylor swift',
#   'its about time lizzo',
#   'caldwell presbyterian church',
#   'caldwell presbyterian church'],
#  'BQXA68529': ['tim conway elephant', 'tim conway elephant story '],
#  'BRDS42585': ['noel lauren daigle',
#   'breath of heaven amy grant',
#   'noel lauren daigle',
#   'breath of heaven amy grant',
#   'noel lauren daigle',
#   'breath of heaven amy grant',
#   'nutcracker suite selections ',
#   'mary did you know mark lowry',
#   'i plead the blood',
#   'i plead the blood hemphills',
#   'i plead the blood hemphills',
#   'i plead the blood',
#   'oh beautiful star of bethlehem',
#   'oh beautiful star of bethlehem patty loveless',
#   'katy nichole',
#   'noel lauren daigle',
#   'i claim the blood',
#   'katy nichole in jesus name',
#   'priceless for king and country',
#   'priceless for king and country',
#   'priceless for king and country',
#   'phil wickham',
#   'flip n fun gainesville ',
#   'flip n fun gainesville ',
#   'flip n fun gainesville ',
#   'noel lauren daigle',
#   'lauren lake%27s paternity court',
#   'carly mc shorts',
#   'darman',
#   'darman',
#   'darman',
#   'darman sailish movie'],
#  'BRIH50597': ['hero wars frozen treasure season', 'lotro yule festival'],
#  'BRXM29848': ['amphibia the hardest thing',
#   'pillow talk lyrics',
#   'pillow talking',
#   'the owl house yesterday%27s lie',
#   'the owl house yesterday%27s lie',
#   'the owl house yesterday%27s lie',
#   'the owl house yesterday%27s lie',
#   'the owl house yesterday%27s lie',
#   'the owl house yesterday%27s lie',
#   'the owl house yesterday%27s lie',
#   'the owl house yesterday%27s lie',
#   'the owl house yesterday%27s lie camila noceda',
#   'the owl house yesterday%27s lie vee breaks the reflection'],
#  'BSBX66059': ['osby berry so will i',
#   'osby berry so will i',
#   'osby berry so will i',
#   'taya so will i',
#   'worthy of my song'],
#  'BSTN58821': ['ms. frazzled',
#   'ms. frazzled',
#   'ms. frazzled',
#   'mark woodley weather',
#   'mark woodley weather',
#   'mark woodley weather',
#   'mark woodley weather',
#   'cook%27s illustrated thai grilled beef salad',
#   'how to kettlebell',
#   'how to kettlebell',
#   'steve harvey doesn%27t want to host family feud anymore',
#   'microwave poached eggs',
#   'america%27s test kitchen migas',
#   'rachel ray duvet cover',
#   'rachel ray duvet cover',
#   'mo mountain mutts',
#   'mo mountain mutts',
#   'panettone',
#   'graco snugride 35 lite lx infant car seat stroller',
#   'graco snugride 35 lite lx infant car seat stroller',
#   'graco snugride 35 lite lx infant car seat stroller',
#   'graco snugride 35 lite lx infant stroller',
#   'graco snugride 35 lite dlx stroller'],
#  'BTHI11724': ['la bodega made in cuba',
#   'PORTA PAPELES',
#   'la bodega made in cuba',
#   'la bodega made in cuba',
#   'la bodega univista tv',
#   'portapapeles windows 10',
#   'la bodega made in cuba',
#   'DONDE ESTA EL PORTAPAPELES',
#   'EL ANTIGUO EGIPTO',
#   'la bodega made in cuba',
#   'https%3A%2F%2Fyoutu.be%2FfNLa0PP9Y3A',
#   'LOS BUKIS',
#   'la bodega made in cuba ultimo capitulo',
#   'alvarez guedes chistes',
#   'enjoy the silence subtitulos espa%C3%B1ol',
#   'chistes canadienses 2022',
#   'chistes canadienses 2022',
#   'chistes canadienses 2022',
#   'chistes canadienses 2022',
#   'chistes canadienses 2022',
#   'chistes canadienses 2022',
#   'chistes canadienses 2022',
#   'chistes canadienses 2022',
#   'chistes canadienses 2022',
#   'chistes canadienses 2022',
#   'chistes canadienses 2022',
#   'chistes canadienses 2022',
#   'chistes canadienses 2022',
#   'chistes canadienses 2022',
#   'chistes canadienses 2022',
#   'chistes canadienses 2022',
#   'chistes canadienses 2022',
#   'chistes canadienses 2022',
#   'chistes canadienses 2022',
#   'chistes canadienses 2022',
#   'chistes canadienses 2022',
#   'chistes canadienses 2022',
#   'chistes canadienses 2022',
#   'chistes canadienses 2022',
#   'chistes canadienses 2022',
#   'caso cerrados mi suegra',
#   'caso cerrado la suegra',
#   'caso cerrado vieja loca',
#   'caso cerrado 2008 - juanito y la abuela loca (1%2F2) ',
#   'veredicto final divorcio de rogelio y kenia',
#   'veredicto final divorcio de rogelio y kenia',
#   'veredicto final divorcio de rogelio y kenia',
#   'veredicto final divorcio de rogelio y kenia',
#   'veredicto final divorcio de  a quien le dio de comer',
#   'veredicto final divorcios',
#   'veredicto final  a quien le di de comer',
#   'veredicto final  a quien le di de comer',
#   'veredicto final capitulos completos',
#   'veredicto final ',
#   'veredicto final  divorcio autorizados',
#   'JORGE PERROGOURA',
#   'CALEIDOSCOPIO',
#   'la casa de papel temporada 1',
#   'peliculas en espanol completas gratis de accion 2021',
#   'peliculas en espanol completas gratis de accion 2021',
#   'peliculas en espanol completas gratis de accion 2021',
#   'peliculas cubanas completas comedias',
#   'peliculas cubanas completas comedias',
#   'peliculas cubanas completas comedias',
#   'peliculas dominicanas de humor completas',
#   'MEJORES JUGADAS EN FUTNOL',
#   'MEJORES JUGADAS EN FUTNOL'],
#  'BUFK86104': ['hit me with your best shot',
#   'hit me with your best shot solo',
#   'hit me with your best shot solo',
#   'hit me with your best shot solo',
#   'chain of fools',
#   'chain of fools',
#   'chain of fools',
#   'chain of fools',
#   'chain of fools',
#   'Fooled Around And Fell In Love%2FMellisa Lambert',
#   'Fooled Around And Fell In Love%2FMellisa Lambert',
#   'Fooled Around And Fell In Love%2FMellisa Lambert',
#   'hit me with your best shot solo',
#   'Fooled Around And Fell In Love%2FMellisa Lambert',
#   'hit me with your best shot solo',
#   'you%27re no good lesson ',
#   'you%27re no good lesson ',
#   'you%27re no good lesson ',
#   'you%27re no good lesson ',
#   'you%27re no good lesson ',
#   'you%27re no good lesson ',
#   'you%27re no good lesson ',
#   'you%27re no good lesson ',
#   'you%27re no good lesson ',
#   'you%27re no good lesson ',
#   'you%27re no good lesson ',
#   'you%27re no good lesson ',
#   'you%27re no good lesson ',
#   'you%27re no good lesson ',
#   'lesson When Will I Be Loved - Linda Ronstadt',
#   'when will i be loved - linda ronstadt',
#   'you%27re no good lesson ',
#   'linda ronstadt you%27re no good guitar solo',
#   'sunrise norah jones',
#   'sunrise norah jones',
#   'when will i be loved - linda ronstadt',
#   'linda ronstadt you%27re no good guitar solo',
#   'you%27re no good lesson ',
#   'you%27re no good lesson ',
#   'you%27re no good solo lesson',
#   'you%27re no good solo lesson',
#   'you%27re no good solo lesson',
#   'you%27re no good solo lesson',
#   'you%27re no good solo lesson ronstadt',
#   'you%27re no good solo lesson ronstadt',
#   'you%27re no good solo lesson ronstadt',
#   'you%27re no good solo lesson ronstadt',
#   'when will i be loved cover',
#   'when will i be loved cover',
#   'Patsy Cline-Walkin%27 After Midnight ',
#   'Patsy Cline-Walkin%27 After Midnight CHORDS',
#   'Patsy Cline-Walkin%27 After Midnight CHORDS',
#   'Patsy Cline-Walkin%27 After Midnight CHORDS',
#   'Patsy Cline-Walkin%27 After Midnight CHORDS',
#   'Patsy Cline-Walkin%27 After Midnight CHORDS',
#   'Patsy Cline-Walkin%27 After Midnight CHORDS',
#   'Patsy Cline-Walkin%27 After Midnight CHORDS',
#   'Patsy Cline-Walkin%27 After Midnight CHORDS',
#   'Patsy Cline-Walkin%27 After Midnight CHORDS',
#   'Patsy Cline-Walkin%27 After Midnight CHORDS',
#   'crazy patsy cline',
#   'listen to the music doobie brothers',
#   'listen to the music doobie brothers',
#   'doobie brothers listen to the music guitar lesson',
#   'doobie brothers listen to the music guitar lesson',
#   'bad case of loving you robert palmer chords',
#   'bad case of loving you robert palmer chords',
#   'bad case of loving you robert palmer chords',
#   'bad case of loving you robert palmer chords',
#   'bad case of loving you robert palmer chords',
#   'bad case of loving you robert palmer ',
#   'bad case of loving you robert palmer ',
#   'bad case of loving you robert palmer ',
#   'bad case of loving you robert palmer chords',
#   'bad case of loving you robert palmer chords',
#   'bad case of loving you robert palmer chords',
#   'bad case of loving you robert palmer chords',
#   'bad case of loving you robert palmer chords',
#   'bad case of loving you robert palmer chords',
#   'bad case of loving you robert palmer chords',
#   'bad case of loving you robert palmer chords',
#   'bad case of loving you robert palmer chords',
#   'something more sugarland',
#   'sugarland something more guitar lesson ',
#   'sugarland something more guitar lesson ',
#   'sugarland something more guitar lesson ',
#   'sugarland something more guitar ',
#   'sugarland something more guitar ',
#   'sugarland something more guitar ',
#   'sugarland something more guitar ',
#   'why haven%27t i heard from you reba lyrics',
#   'why haven%27t i heard from you reba lyrics',
#   'why haven%27t i heard from you reba lyrics',
#   'you don%27t have to go home gretchen wilson ',
#   'you don%27t have to go home gretchen wilson ',
#   'you don%27t have to go home gretchen wilson lesson chords',
#   'you don%27t have to go home gretchen wilson lesson chords',
#   'why haven%27t i heard from you lesson chords',
#   'why haven%27t i heard from you lesson chords',
#   'why haven%27t i heard from you lesson chords',
#   'redneck woman',
#   'redneck woman gretchen wilson',
#   'redneck woman gretchen wilson',
#   'unchain my heart joe cocker',
#   'unchain my heart guitar lesson',
#   'unchain my heart guitar lesson',
#   'unchain my heart guitar lesson',
#   'unchain my heart guitar lesson',
#   'unchain my heart guitar lesson',
#   'unchain my heart guitar lesson',
#   'save the last dance for me drifters',
#   'save the last dance for me drifters',
#   'save the last dance for me drifters',
#   'save the last dance for me drifters',
#   'save the last dance for me drifters',
#   'save the last dance for me drifters',
#   'save the last dance for me drifters',
#   'save the last dance for me drifters',
#   'save the last dance for me drifters',
#   'save the last dance for me drifters',
#   'save the last dance for me drifters',
#   'save the last dance for me drifters',
#   'save the last dance for me drifters',
#   'save the last dance for me drifters',
#   'save the last dance for me drifters',
#   'save the last dance for me drifters',
#   'save the last dance for me drifters',
#   'save the last dance for me drifters',
#   'save the last dance for me drifters',
#   'save the last dance for me drifters',
#   'save the last dance for me drifters',
#   'save the last dance for me drifters',
#   'bad case of loving you robert palmer',
#   'bad case of loving you robert palmer guitar lesson ',
#   'locked out of heaven lesson',
#   'locked out of heaven lesson'],
#  'BUKN47281': ['car battery terminal corrosion prevention ',
#   'car battery terminal corrosion prevention ',
#   'Mafiti Computer Office Keyboard Wired USB',
#   'best acklit keyboard',
#   'best backlit keyboard',
#   'best backlit keyboard',
#   'best backlit keyboard',
#   'Mafiti Computer Office Keyboard Wired USB',
#   '5-Stage BoAir Electrostatic Air   ',
#   'yolobox',
#   'yolobox mini',
#   'yoko bo',
#   'yoko box',
#   'yogo box',
#   'story box',
#   'kelly%27s heroes',
#   'how to stop spam calls on iphone ',
#   'nenner',
#   'est places live arizona',
#   'vika living',
#   'phoeni avoid areas',
#   'phoenix avoid areas',
#   'phoenix worst areas',
#   'phoenix worst areas',
#   'buckeye az',
#   'buckeye az',
#   'modern prefab homes ',
#   'modern prefab homes ',
# ...
#   'criminal minds season 1',
#   'ecriminal minds season 1 full',
#   'ecriminal minds season 1 full episodes',
#   'criminal minds season 1 full episodes',
#   'crime hunter audio game',
#   'crime hunter audio game',
#   'crime hunter 2.0 audio game',
#   'crime hunter 2.0 audio game',
#   'crime hunter 2.0 audio game',
#   'crime hunter 2.0 audio game'],
#  'SPYT64655': ['you need to calm down taylor swift',
#   'emily osment',
#   'emily osment ep',
#   'do they know it%27s christmas 2014'],
#  'SPZJ84386': ['babrie solider breathe',
#   'creative destruction',
#   'lil wayne she will',
#   'lil wayne she will',
#   'neffex soldier',
#   'creative destruction',
#   'creative destruction',
#   'creative destruction',
#   'fortnite',
#   'fortnite',
#   'she will lil wayne',
#   'childish gambino 3005',
#   'notled lemon',
#   'notled lemonade',
#   'notled lemonade',
#   'creative destruction mobile',
#   't.a.t.u all about us',
#   'billie eilish everything i wanted',
#   'travis scott',
#   'neffex grateful',
#   'babrie solider breathe',
#   'babrie solider breathe',
#   'babrie solider breathe',
#   'boyfriend dove cameron',
#   'she will lil wayne',
#   'telepatia'],
#  'SQKL20297': ['thom yorke', 'atoms for peace', 'noclip dwarf fortress'],
#  'SQSI73245': ['betty taylor swift lyrics',
#   'paper rings taylor swift lyrics',
#   'paper rings taylor swift lyrics',
#   'not again jenna raine',
#   'enough for u olivia rodrigo',
#   'surf curse disco lyrics',
#   'ballad of a badman lyrics',
#   'jungle keep moving lyrics',
#   'jungle all of the time lyrics',
#   'what%27s the matter with you',
#   'tory lanez ballad badman instrumental',
#   'tory lanez ballad badman lyrics',
#   'taylor swift midnight lyrics',
#   'lavender haze taylor swift',
#   'what%27s the matter with you',
#   'red hot chili peppers go robot lyrics',
#   'red hot chili peppers go robot lyrics',
#   'jungle keep moving lyrics',
#   'jungle all of the time lyrics',
#   'love is a battlefield lyrics',
#   'not again jenna raine',
#   'rent free jenna raine ',
#   'alpharad 3d world',
#   'alpharad 3d world',
#   'alpharad 3d world',
#   'reality house season 3 episode 4',
#   'reality house season 3 episode 5',
#   'traffic lights sara kays',
#   'when you look at me sara kays',
#   'betty taylor swift',
#   'paris taylor swift',
#   'midnight rain taylor swift',
#   'bejeweled taylor swift',
#   'starry eyed jane and the boy',
#   'deliah lyrics',
#   'bubble up',
#   'deliah we are the good lyrics',
#   'alpharad',
#   'karma taylor swift',
#   'midnight rain taylor swift',
#   'cardigan taylor swift',
#   'alpharad 3d world',
#   'alpharad ruin career mario party',
#   'wouldve couldve shouldve taylor swift',
#   'taylor swift all too well',
#   'taylor swift all too well 10 minute version lyrics',
#   'taylor swift all too well 10 minute version lyrics'],
#  'SRZQ84981': ['chromebook side by side windows',
#   'chromebook side by side windows',
#   'chromebook side by side windows',
#   'horimiya live action',
#   'horimiya live action'],
#  'SSFS71067': ['the%20real%20carbonara', 'the real carbonara'],
#  'SSHB40293': ['warbird news',
#   'elonjet',
#   'elonjet&sp=CAI%253D',
#   'diresta jimmy',
#   'Ren %26 Stimpy%27s Crock O%27 Christmas',
#   'don%27t forget to fill your father%27s boots with coleslaw',
#   'ren %26 stimpy',
#   'catching up with max and jose',
#   'Happy Happy Joy Joy%3A The Ren %26 Stimpy Story',
#   'bartees strange',
#   'jeopardy december 12 2022 full episode',
#   'jeopardy december 19 2022 full episode',
#   'maddow ultra podcast',
#   'rachel maddow presents%3A ultra podcast episode 1',
#   '%22rachel maddow%22',
#   '%22rachel maddow%22 -msnbc',
#   'jayne mansfield',
#   'krautrick faust',
#   'charles de gaulle  band',
#   'charles de goal',
#   'can monster movie',
#   'silicon teens',
#   'silicon teens',
#   'fad gadget',
#   'talk talk today',
#   'talk talk today',
#   'berlin sex live',
#   'dancing in berlin',
#   'no more words berlin',
#   'masquerade berlin',
#   'love is blue',
#   'cardiac ablation',
#   'jeopardy december 19 2022 full episode',
#   'jeopardy december 23 2022 full episode',
#   'jeopardy december 23 2022 full episode',
#   'jeopardy december 23 2022 full episode',
#   'jeopardy december 22 2022 full episode',
#   'jeopardy december 12%2F22%2F2022',
#   'jeopardy 12%2F22%2F2022',
#   'sage stuffing'],
#  'SSQD86224': ['sbs awards', 'enypen', 'enypen'],
#  'SSQF59100': ['pillsbury doughboy poop',
#   'pillsbury doughboy parody',
#   'stuart look what i can do',
#   'comfort women',
#   'comfort women korea',
#   'comfort women',
#   'meghan markle horrible bosses'],
#  'STAX68114': ['shopify dropshipping',
#   '3d print neon sign',
#   '3d print neon sign'],
#  'STEQ75881': ['brisket recipes'],
#  'STIW93615': ['sky news ukraine',
#   'sky news ukraine 93rd',
#   'hell on wheels trailer',
#   'sky news ukraine',
#   'sky news ukraine 93rd',
#   'emily davis walk away',
#   'don%27t sell me short ',
#   'dawes a little bit of everything',
#   'dawes a little bit of everything',
#   'dawes a little bit of everything',
#   'dawes a little bit of everything lyrics',
#   'dawes a little bit of everything',
#   'a little bit of everything dawes',
#   'dismemberment plan time bomb'],
#  'STXR86378': ['jacob geller who%27s afraid of modern art',
#   'plastic love',
#   'lindsay ellis',
#   'tokyo godfather',
#   'chris fleming christmas',
#   'subaru baja repair'],
#  'SUDA91111': ['tony robbins',
#   'instant pot vegan soup white beans and rosemary',
#   'instant pot soup white beans and rosemary',
#   'fasolada instand pot',
#   'tradewater offsets',
#   'fifa world cup final argentina vs france',
#   'fifa world cup final argentina vs france ceremony'],
#  'SUHF23261': ['brez',
#   'honey baked ham',
#   'erb',
#   'everything you need to know about green hell',
#   'numotthenummy',
#   'aviators',
#   'numotthenummy',
#   'crokeyz',
#   'nexpo',
#   'eudoxia mysteries'],
#  'SUOE99849': ['2022 easiest way get 100.00 in paypal in 1 hour',
#   'paypal free money 2022',
#   'highest fastest paypal payment watching videos',
#   'flash coin review 2022 english',
#   '2022 wheat pennies value',
#   '1940 no mint mark',
#   'wheat pennies buyers near me'],
#  'SVSG19814': ['Sunsleeper', 'Human League'],
#  'SWVE30381': ['telemundo argentina',
#   'argentina tv',
#   'argentina tv',
#   'argentina tv',
#   'laughter %E9%AB%AD%E7%94%B7'],
#  'SXJH11321': ['gpt interview',
#   'gpt-3',
#   'first time overwatch player',
#   'non gamer plays overwatch',
#   'demon hunter collapsing'],
#  'SXKB60557': ['f150 apim replacement ',
#   'f150 apim replacement',
#   'lvitv',
#   '2017 f150 ecoboost starter replacement '],
#  'SXRV56059': ['freaky t', 'schience daily '],
#  'SYIW93238': ['llamas with hats',
#   'llama llama red pajama',
#   'children%27s book freestyle'],
#  'SYLF30005': ['portrait here we go again remix',
#   'portrait here we go again remix',
#   'portrait here we go again remix',
#   'portrait here we go again remix',
#   'portrait here we go again dj cassidy',
#   'portrait here we go again soul train',
#   'dj cassidy pass the mic',
#   'portrait here we go again remix',
#   'portrait here we go again remix',
#   'fantasia i feel beautiful',
#   'fantasia i feel beautiful',
#   'justin timberlake summer love%2Fset the mood',
#   'justin timberlake summer love%2Fset the mood',
#   'changing faces come over',
#   'lil freak usher',
#   'aaliyah i%27m so into you ',
#   'paula abdul vibeology',
#   'paula abdul vibeology',
#   'love don%27t live gangsta boo ',
#   'god we need you now struggle jennings lyrics',
#   'careless whisper lyrics',
#   'careless whisper anth conor maynard %26 corey nyell',
#   'can i tink',
#   'red kingdom tech n9ne',
#   'usher tell me',
#   'golden hour jvke',
#   'benedetta caretta',
#   'benedetta caretta you raise me up',
#   'benedetta caretta you raise me up',
#   'my first love avant'],
#  'SZEJ82243': ['british bulldogs matilda kidnapped',
#   'british bulldogs matilda kidnapped',
#   'british bulldogs matilda kidnapped',
#   'british bulldogs matilda kidnapped',
#   'british bulldogs matilda kidnapped',
#   'british bulldogs matilda kidnapped',
#   'rivers casino portsmouth',
#   'rivers casino portsmouth',
#   'rivers casino portsmouth',
#   'bruno sammartino all japan',
#   'bruno sammartino all japan',
#   'lana violet',
#   'kenny omega will ospreay',
#   'kenny omega will ospreay',
#   'jesse leroy brown remains',
#   'jesse leroy brown crash site',
#   'keiji mutoh at antonio inoki%27s funeral',
#   'goldberg vs dolph ziggler',
#   'cm punk aew theme',
#   'great muta theme',
#   'great muta theme',
#   'nxt november 20 2019',
#   'nxt november 20 2019',
#   'space x spacesuit',
#   'inspiration4 spacex',
#   'the elite vs united empire',
#   'bow wow aew',
#   'neutral nations supervisory commission',
#   'apollo soyuz test project',
#   'the elite vs united empire',
#   'rivers casino portsmouth',
#   'the acclaimed disses wwe',
#   'the acclaimed disses wwe',
#   'the acclaimed disses wwe',
#   'the acclaimed disses wwe'],
#  'SZVS69472': ['no cap i%27m a little drunk',
#   'no cap i%27m a little drunk',
#   'no cap i%27m a little drunk',
#   'no cap i%27m a little drunk meme',
#   'will i am cnn hologram',
#   'will i am cnn hologram',
#   'bipedal cat',
#   'Gervon Dexter',
#   'jimmy d spongebob ',
#   'walter white jesse pinkman NFL',
#   'jalen reagor dropped passes ',
#   'jalen reagor dropped passes ',
#   'nelson agholor baby drop',
#   'nelson agholor drops',
#   'nelson agholor drops',
#   'nelson agholor drops',
#   'so long gay bowser',
#   'double toasted',
#   'three person team vs top secrets',
#   'cloud are you seriously that desperate ',
#   'bk have it your way commercial meme',
#   'bk have it your way commercial NFL'],
#  'TACS11129': ['oyerepa afutuo',
#   'una mattina',
#   'oltremare ludovico einaudi',
#   'jamari',
#   'nasa santigold',
#   'jamari',
#   'jamari',
#   'jamari',
#   'wallstreetbets',
#   'wallstreetbets',
#   'gossip 24 avenue',
#   'gossip 24 avenue',
#   'if tomorrow starts without me poem',
#   'rumi',
#   'love explained rabbi',
#   'gossip24 avenue'],
#  'TAKA31922': ['how to smile at strangers',
#   'over 50 workout women',
#   'over 50 workout women&sp=CAI%253D',
#   'dance how to learn dance',
#   'dance how to learn dance&sp=CAI%253D',
#   'dance how to learn dance&sp=CAISBAgFEAE%253D'],
#  'TBAA33799': ['samsung 85q80b review',
#   'lg 86NANO75UQA',
#   'lg 86nano75uqa',
#   'lg 86nano75uqa',
#   'lg 86nano75uqa 2022',
#   'samsung 85q80b review',
#   'samsung qn85q80bafxza vs lg 86qned85',
#   'lg 86nano90upa',
#   'lg 86qned90upa review',
#   'lg 86qned80uqa',
#   'lg 86qned80uqa',
#   'hisense 85a7h',
#   'hisense 85a7h',
#   'hisense 85a7h',
#   'lg-86nano75uqa',
#   'lg nanocell 75 series 2022',
#   'hisense 85a7h',
#   'hisense 85a7h',
#   'sony 85x80ck',
#   'lg 86',
#   'lg 86 uq8000 review',
#   '8newsnow fireworks',
#   '8newsnow fireworks 2023',
#   'nokia g400 5g'],
#  'TBGR97558': ['wild adventures',
#   'dontgiveup wild adventures',
#   'dontgiveup wild adventure',
#   'dontgiveup',
#   'dontgiveup&sp=EgIQAg%253D%253D',
#   'dontgiveup',
#   'dontgiveup wild adventure',
#   'dontgiveup wild adventure&sp=EgIIAw%253D%253D',
#   'dontgiveup wild adventure&sp=EgQIAhAB',
#   'dontgiveup wild adventures',
#   'dontgiveup wild adventures&sp=EgIIAg%253D%253D',
#   'dontgiveup wild adventures&sp=EgQIAxAB',
#   'dontgiveup wild adventures ride',
#   'dontgiveup wild adventures&sp=EgQIAxAB',
#   'dontgiveup wild adventures&sp=EgQIAhAB',
#   'dontgiveup wild adventures&sp=EgIIAg%253D%253D',
#   'dontgiveup wild adventures&sp=EgIIAg%253D%253D',
#   'nevergiveup wild adventures',
#   'catechism in a year podcast'],
#  'TBJD93699': ['big ron jones',
#   'cookieswirlc',
#   'cookieswirlc',
#   'cookie swirl c shopkins'],
#  'TBMG68876': ['qi',
#   'qi',
#   'qi full episode',
#   'qi full episode 2022',
#   'Ludacris',
#   'only connect',
#   'remove yellow stains from linoleum',
#   'remove yellow stains from linoleum',
#   'remove yellow stains from linoleum',
#   'remove yellow stains from linoleum',
#   'yellow stains from linoleum',
#   'Pusha T %E2%80%93 It%E2%80%99s Almost Dry',
#   'only connect',
#   'Black Star%2C No Fear of Time',
#   'Vince Staples%2C Ramona Park Broke My Heart',
#   'Black Star%2C No Fear of Time',
#   'Pusha T %E2%80%93 It%E2%80%99s Almost Dry',
#   'Pusha T %E2%80%93 It%E2%80%99s Almost Dry',
#   'Black Star%2C No Fear of Time',
#   'Vince Staples%2C Ramona Park Broke My Heart',
#   'Rhod Gilbert%3A Stand Up to Shyness',
#   'Renfield',
#   'closer look',
#   'seth meyers corrections',
#   'seth meyers closer look',
#   'seth meyers',
#   'late night with seth meyers',
#   'greg davies',
#   'Pusha T %E2%80%93 It%E2%80%99s Almost Dry',
#   'Rhod Gilbert%3A Stand Up to Shyness',
#   'Rhod Gilbert%3A Stand Up to Shyness',
#   'corrections seth meyers',
#   'Black Star%2C No Fear of Time',
#   'Vince Staples%2C Ramona Park Broke My Heart',
#   'sona rapper',
#   ' %E2%80%9CAlive on Arrival%E2%80%9D by Ice Cube (%E2%80%9CFame%E2%80%9D)',
#   '%E2%80%9CBeen Around the World%E2%80%9D',
#   '%E2%80%9CTakeover%E2%80%9D by Jay-Z',
#   '8 out of 10 cats does countdown 2022',
#   'would i lie to you 2022',
#   'would i lie to you 2022',
#   'trailer',
#   'Tipping Point Lucky Stars',
#   'tipping point lucky stars jimmy carr',
#   'tipping point lucky stars ',
#   'tipping point lucky stars ',
#   'tipping point lucky stars series 1 episode 3',
#   'tipping point lucky stars series 3 episode 1',
#   'tipping point lucky stars 2016 ',
#   'tipping point lucky stars jimmy carr',
#   'tipping point lucky stars full episodes',
#   'tipping point lucky stars series 1',
#   'tipping point lucky stars series 2',
#   'tipping point lucky stars series 6',
#   'the tomorrow people',
#   'al pacino'],
#  'TBOJ52494': ['opus number 1',
#   'lucy show 2 1',
#   'lucy show cleopatra',
#   'lucy show cleopatra',
#   'lucy show 2 1',
#   'crash course',
#   'crash course world history',
#   'crash course european history',
#   'crash course history',
#   'crash course european history',
#   'golden girls rose gandhi',
#   'fireplace',
#   'fireplace cabin',
#   'fireplace cabin',
#   'fireplace cabin',
#   'sean kingston beautiful girls'],
#  'TCJS64012': ['michael scott spaceman',
#   'michael scott spaceman season 5',
#   'michael scott swing season 5',
#   'office swing season 5',
#   ' RACLETTE',
#   'Fabric Texture In Photoshop',
#   'Fabric Texture In Photoshop',
#   'Fabric Texture In Photoshop',
#   'Mr. Brightside (Jacques Lu Cont%27s Thin White Duke Remix)',
#   'crystal castles',
#   'hello kitty store',
#   'kanye alex jones',
#   'you%27re gonna have to toss me ',
#   'you%27re gonna have to toss me ',
#   'Jimmy Somerville',
#   'erasure&sp=EheSARQKCS9tLzAxNXI2eSoHZXJhc3VyZXgB',
#   'Jimmy Somerville what makes us ',
#   'erasure always robot unicorn attack',
#   'erasure always robot unicorn attack',
#   'erasure&sp=EheSARQKCS9tLzAxNXI2eSoHZXJhc3VyZXgB',
#   'self worth',
#   'self worth',
#   'elemental',
#   'charlie loinnet',
#   'charlie lionnet',
#   'bella poarch',
#   'cdawgva vods',
#   'cdawgva ',
#   'markiplier thankmas'],
#  'TCJW86734': ['donald trump announcement',
#   'wrecked imagine dragons',
#   'imei fire 8.0',
#   'find imei fire 8.0',
#   'find imei fire 8.0 tablet',
#   'find imei on  amazn  fire 8.0 tablet'],
#  'TDQL59159': ['nle choppa',
#   'juice wrld',
#   'bulldog mindset',
#   'robbery juice wrld',
#   'what do m%26m and have in common'],
#  'TDYW88360': ['kelly osbourne and child',
#   'floor ab exercis',
#   'floor exercises for love handles ',
#   'floor exercises for love handles ',
#   'floor exercises for love handles ',
#   'floor exercises for love handles ',
#   'floor exercises for love handles over 50'],
#  'TEDR34078': ['opium cigarettes',
#   'opium cigarettes',
#   'opium cigarettes',
#   'opium pipes'],
#  'TERI37054': ['home assistant', 'french drain%5C', 'picroft', 'picroft'],
#  'TERK43200': ['deadline white house',
#   'deadline white house 12%2F14%2F22',
#   'deadline white house 12%2F14%2F22',
#   'deadline white house',
#   'deadline white house 12%2F15%2F22',
#   'deadline white house 12%2F16%2F22'],
#  'TEZG96181': ['bloopers'],
#  'TFCU55512': ['and tiara well and care of easy baby', 'babyface ray'],
#  'TFYT66132': ['john renbourn',
#   'subnautica nuclear reactor',
#   'subnautica lava zone alien base location',
#   'subnautica lava zone alien base location',
#   'zoom r20',
#   'modest mouse float on',
#   'modest mouse float on snl',
#   'here comes the sun lead guitar ',
#   'glory daze',
#   'glory daze tv series'],
#  'THSZ63722': ['floor is hot cocoa brain break',
#   'the forest final boss',
#   'kindergarten',
#   'kindergarten coryxkenshin'],
#  ...}

# %%
watches = pd.read_pickle('../../data/user-level-data')
df = pd.read_pickle('../../data/datasets/raw-video-level-watches')
videos = pd.read_pickle('../../data/videos_raw_metadata')
title_embeddings = pd.read_pickle('../../data/embeddings/title-autoencoded')
title_openai_embeddings = pd.read_pickle('../../data/embeddings/openai-title')
tag_embeddings = pd.read_pickle('../../data/embeddings/tag_embeddings.pkl')
topic_embeddings = pd.read_pickle('../../data/embeddings/topic_embeddings.pkl')

# %%
videos = clean(meta_data, titles=embeddings)

# %%
users = list(set(df['userId']))

data = dict()

for user in tqdm(users):
    data[user] = df[df['userId'] == user].sort_values('date')

sessions = dict()
for user in tqdm(users):
    sessions[user] = []
    sess = data[user][['date', 'url', 'is_video', 'upnext_content']].to_dict('records')
    session = []
    session_active = False
    for watch in sess:
        # when waiting for first video in a session
        if not session_active and watch['is_video']:
            session = []
            session.append(watch)
            session_active = True

        # back to back videos
        elif session_active and watch['is_video']:
            upnexts = decode_upnext(session[-1]['upnext_content'])
            this_url = get_id(watch['url'])
            if this_url in upnexts:
                session.append(watch)


        # if next watch is not video when session active
        elif session_active and not watch['is_video']:
            session_active = False
            if len(session) > 1:
                sessions[user].append(session)
            session = []
# Out:
#   0%|          | 0/2171 [00:00<?, ?it/s]
#   0%|          | 0/2171 [00:00<?, ?it/s]

# %%
session_users = []
for user in sessions:
    if len(sessions[user]) != 0:
        session_users.append(user)

# %%
watches = dict()
for user in tqdm(session_users):
    watches[user] = []
    for session in sessions[user]:
        for watching, next_watch in zip(session[:-1], session[1:]):
            watch = dict()
            watch['playing'] = get_id(watching['url']) 
            watch['upnext'] = decode_upnext(watching['upnext_content']) 
            watch['selected'] = get_id(next_watch['url'])
            watches[user].append(watch)
# Out:
#   0%|          | 0/1289 [00:00<?, ?it/s]

# %%
def get_history_and_training(watch):
    # 20% of the watch list is used for history rest is used for training
    history = []
    training = []

    for i in range(len(watch)):
        if i < len(watch) * 0.2:
            history.append(watch[i])
        else:
            training.append(watch[i])
    return history, training

history = dict()
training = dict()

for user in tqdm(watches):
    history[user] = []
    training[user] = []
    h, t = get_history_and_training(watches[user])
    history[user] = h
    training[user] = t
# Out:
#   0%|          | 0/1289 [00:00<?, ?it/s]

# %%
# Out:
# array([-0.02052369, -0.00394123,  0.00676498, -0.02789925,  0.0364079 ,
#         0.00423158,  0.01893815, -0.01024528, -0.03310304, -0.01286414,
#        -0.00615279,  0.02214764, -0.03293549,  0.00024888,  0.00529397,
#        -0.01657577, -0.02752809,  0.01507695, -0.00357913, -0.01581683,
#        -0.0258556 ,  0.01929254,  0.02471216,  0.02040244,  0.00890152,
#        -0.01546264,  0.00694602,  0.00397866,  0.00974122,  0.01126551,
#        -0.00528934,  0.01407733, -0.01547308, -0.03903421,  0.01192805,
#         0.00990158,  0.02335085, -0.01921366, -0.016178  ,  0.03032142,
#        -0.01173447,  0.01126173, -0.01118469,  0.00057627, -0.02390211,
#         0.00903398, -0.02650922, -0.00192399,  0.01496556, -0.01324484,
#         0.00266217, -0.03945154,  0.00449591,  0.00193637, -0.01711477,
#         0.02369141, -0.01885802, -0.00041714, -0.02460242, -0.01745125,
#        -0.00019955,  0.00628997,  0.00455425,  0.00320548,  0.00558458,
#        -0.00320261, -0.00017512,  0.00261015, -0.00067335, -0.01929031,
#         0.00111482,  0.01363278,  0.00608864,  0.00037909,  0.02376767,
#        -0.00360196, -0.01350546, -0.0199197 ,  0.01585018,  0.0117649 ,
#        -0.01005676,  0.01752588, -0.01716978,  0.01245739, -0.00044736,
#         0.0092096 , -0.00733408, -0.02526437, -0.00875789,  0.00559968,
#         0.01199899, -0.0014502 ,  0.00055523, -0.0155715 ,  0.03496094,
#        -0.00833867, -0.00086587,  0.01540636, -0.00730821,  0.0229848 ,
#        -0.00118499,  0.00828741,  0.01219234, -0.00759965, -0.01636888,
#        -0.03998277,  0.01007381,  0.02284099,  0.00947074,  0.01327707,
#        -0.04471378,  0.02749506, -0.00734454,  0.01242069, -0.02239834,
#         0.02094616, -0.01247023,  0.02169361, -0.0149961 , -0.00243262,
#        -0.00369339, -0.01043681,  0.00055173, -0.0207613 ,  0.01323464,
#         0.0015879 , -0.01259952, -0.00296076], dtype=float32)

# %%
history_embeddings = dict()

for user in tqdm(history):
    history_embeddings[user] = []
    for watch in history[user]:
        if watch['playing'] in videos:
            emb = np.array(embeddings[videos[watch['playing']]['title']])[0]
            history_embeddings[user].append(emb)
        else:
            history_embeddings[user].append(np.zeros(128))
# Out:
#   0%|          | 0/1289 [00:00<?, ?it/s]

# %%
pkl.dump(history_embeddings, open('../../data/embeddings/history_embeddings-todo', 'wb'))
